# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('India_GDP.csv')
data
# Out:
#     Unnamed: 0  Year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0            0  2021             3173.40                182160      8.95
# 1            1  2020             2667.69                154640      6.60
# 2            2  2019             2831.55                165760      3.74
# 3            3  2018             2702.93                159840      6.45
# 4            4  2017             2651.47                158480      6.80
# ..         ...   ...                 ...                   ...       ...
# 57          57  1964               56.48                  9280      7.45
# 58          58  1963               48.42                  8080      5.99
# 59          59  1962               42.16                  7200      2.93
# 60          60  1961               39.23                  6800      3.72
# 61          61  1960               37.03                  6560      0.00
#
# [62 rows x 5 columns]

# %%
data.head()
# Out:
#    Unnamed: 0  Year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0           0  2021             3173.40                182160      8.95
# 1           1  2020             2667.69                154640      6.60
# 2           2  2019             2831.55                165760      3.74
# 3           3  2018             2702.93                159840      6.45
# 4           4  2017             2651.47                158480      6.80

# %%
data.notnull()
# Out:
#     Unnamed: 0  Year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0         True  True                True                  True      True
# 1         True  True                True                  True      True
# 2         True  True                True                  True      True
# 3         True  True                True                  True      True
# 4         True  True                True                  True      True
# ..         ...   ...                 ...                   ...       ...
# 57        True  True                True                  True      True
# 58        True  True                True                  True      True
# 59        True  True                True                  True      True
# 60        True  True                True                  True      True
# 61        True  True                True                  True      True
#
# [62 rows x 5 columns]

# %%
data.tail()
# Out:
#     Unnamed: 0  Year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 57          57  1964               56.48                  9280      7.45
# 58          58  1963               48.42                  8080      5.99
# 59          59  1962               42.16                  7200      2.93
# 60          60  1961               39.23                  6800      3.72
# 61          61  1960               37.03                  6560      0.00

# %%
data=data.drop(['Unnamed: 0'], axis=1)

# %%
data
# Out:
#     Unnamed: 0  Year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0            0  2021             3173.40                182160      8.95
# 1            1  2020             2667.69                154640      6.60
# 2            2  2019             2831.55                165760      3.74
# 3            3  2018             2702.93                159840      6.45
# 4            4  2017             2651.47                158480      6.80
# ..         ...   ...                 ...                   ...       ...
# 57          57  1964               56.48                  9280      7.45
# 58          58  1963               48.42                  8080      5.99
# 59          59  1962               42.16                  7200      2.93
# 60          60  1961               39.23                  6800      3.72
# 61          61  1960               37.03                  6560      0.00
#
# [62 rows x 5 columns]

# %%
 data['Year'].plot(kind='pie')
 plt.title('total number of years [2021-2017]')
 plt.show()

# %%
#plotting a pie chart
#The pie chart is used to study the proportion of numerical data. 
#It shows the proportion of data as a percentage of a whole.
plt.pie(data['Growth %'], labels = data['Year'])
plt.show()
plt.title('Yearly GDP growth')

#plotted for top 5 countries
df_top5=data.head()
plt.pie(df_top5['Growth %'], autopct='%1.1f%%',labels = df_top5['Year'])
plt.title('Yearly GDP for top 5 countries')
plt.show()

# %%
# Bar chart is commonly used to compare teh values of variables at a given point of time
data.plot(kind = 'bar',
        y = 'Growth %',
        x= 'Year',
        color = 'purple',width=0.5,figsize=(5,5))
plt.title('BarPlot')
plt.show()

# %%
#line chart

data.plot(kind = 'line',
        x = 'Year',
        y = 'Growth %',
        color = 'red',marker='o',markerfacecolor = 'green')
plt.show()

# %%
sns.lineplot(data['Year'],data['Growth %'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#plotting scatterplot using seaborn library
sns.scatterplot(data['Year'],data['Growth %'])
color = 'purple'
plt.title('scatterplot')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
 data['Growth %'].plot(kind='box')

# %%
from matplotlib.colorbar import ColorbarBase
colors = sns.color_palette('bright')
#plt.pie(data['Growth %'], labels = data['Year'],colors=colors)
df_top5=data.head()
#We can also add text inside the slices using the autopct parameter.
plt.pie(df_top5['Growth %'], autopct='%1.1f%%',labels = df_top5['Year'])
plt.show()

# %%
explode = [0.3,0.02,0.02,0.02,0.02]
plt.pie(df_top5['Growth %'], autopct='%1.1f%%',labels = df_top5['Year'],colors=colors,explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f51596b0fd0>,
# ...
#  [Text(0.9090730454770926, 1.064700050712408, '2021'),
#   Text(-0.7991900017365292, 0.7846625651350819, '2020'),
#   Text(-1.092500558146011, -0.24666278691901297, '2019'),
#   Text(-0.39972250581073376, -1.0462418068249748, '2018'),
#   Text(0.8871828242317692, -0.6835983004573241, '2017')],
#  [Text(0.5844041006638452, 0.6844500326008337, '27.5%'),
#   Text(-0.44240875096129284, 0.43436677712834887, '20.3%'),
#   Text(-0.6047770946879704, -0.13654547133016787, '11.5%'),
#   Text(-0.22127495857379903, -0.579169571635254, '19.8%'),
#   Text(0.491119063414015, -0.3784204877531615, '20.9%')])

# %%
#explode function
#If we want to create space between each slice so that there will be some offset, we can do that using the explode parameter.
#The value of the explode parameter should be an array of the same length as the input data.
explode = [0.3,0.02,0.02,0.02,0.02]
plt.pie(df_top5['Growth %'], autopct='%1.1f%%',labels = df_top5['Year'],colors=colors,explode=explode)
plt.title('BarPlot for Yearly GDP growth')
plt.show()

# %%
#Bar Chart 
import plotly.express as px
years= list(map(str, range(1960, 2022)))
fig = px.bar(data, x=years,y='Growth %',title= 'Yearly GDP growth')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#pie chart using seaborn
#fig = px.pie(Data1['Growth %'],title='Population of European continent')
#fig.show()
fig = px.pie(data, values='Growth %', names=years, title='Yearly GDP Growth')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(data, x=years, y="Growth %", title='Yearly GDP Growth')
fig.update_traces(line_color='#456988')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.regplot(data['Year'],data['Growth %'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(data['Year'],data['Growth %'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
